# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
print("Hello")
# Out:
# Hello

# %%
data = pd.read_csv("C:/Users/srini/Desktop/IV/UPI/banks.csv")

# %%
data
# Out:
#      Month  No. of Banks live on UPI Volume (in Mn)      Value    Unnamed: 4  \
# 0   Jan-23                       399       8,685.30      1,410           NaN
# 1   Feb-23                       390       7,534.76      1,236           NaN
# 2   Jan-23                       385       8,036.89      1,299           NaN
# 3   Dec-22                       382       7,829.49      1,282           NaN
# 4   Nov-22                       376       7,309.45   1,190.59    11,90,593
# ..     ...                       ...            ...         ...          ...
# 79  Aug-16                        21           0.09       0.00            3
# 80  Jul-16                        21           0.09       0.00            0
# 81  Jun-16                        21              0        -            -
# 82  May-16                        21              0        -            -
# 83  Apr-16                        21              0        -            -
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# ...

# %%
#normal viz

import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/srini/Desktop/IV/UPI/banks.csv")
months = df['Month']
transaction_values = df['Value']

plt.figure(figsize=(10, 6))
plt.style.use('dark_background')
colors = ['yellow']
plt.plot(months, transaction_values, color=colors[0])

plt.ylabel('Month')
plt.xlabel('Transaction Value')
plt.title('Monthly Transaction Value')
plt.grid(True, linestyle='--', alpha=0.5) 
plt.legend(['Transaction Value'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

df = pd.read_csv("C:/Users/srini/Desktop/IV/UPI/banks.csv")

months = df['Month']
transaction_values = df['Value']

fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Monthly Transaction Value Animation')
ax.set_xlabel('Month')
ax.set_ylabel('Value')
ax.set_xlim(months.iloc[0], months.iloc[-1])
ax.grid(True, linestyle='--', alpha=0.5)
line, = ax.plot([], [], color='yellow', label='Transaction Value')
ax.legend(loc='upper left')


def update(frame):
    
    x = months.iloc[:frame+1]
    y = transaction_values.iloc[:frame+1]
    line.set_data(x, y)
    return line,

ani = FuncAnimation(fig, update, frames=len(months), interval=500, blit=True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
